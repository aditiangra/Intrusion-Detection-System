# %%
import tkinter as tk
from tkinter import *
import pandas as pd
from tkinter import filedialog
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import time



# Create a GUI
root = tk.Tk()
root.title("INTRUSION DETECTION SYSTEM")
root.geometry("300x100")


# Create a label to display status
status_label = tk.Label(root, text="INTRUSION DETECTION SYSTEM",font=("Harrington", 20))
status_label.pack()


button_font = ('SimSun', 15)

def open_file():
    file_path = filedialog.askopenfilename()
    if file_path.endswith('.xlsx'):
        df = pd.read_excel(file_path)
        text.delete('1.0', tk.END)
        text.insert(tk.END, df.to_string())
        
        

    




def my_method():
    return "The k-nearest neighbors algorithm, also known as KNN or k-NN, is a non-parametric, supervised learning classifier, which uses proximity to make classifications or predictions about the grouping of an individual data point.For classification problems, a class label is assigned on the basis of a majority vote—i.e. the label that is most frequently represented around a given data point is used. While this is technically considered “plurality voting”, the term, “majority vote” is more commonly used in literature.The distinction between these terminologies is that “majority voting” technically requires a majority of greater than 50%, which primarily works when there are only two categories. When you have multiple classes—e.g. four categories, you don’t necessarily need 50% of the vote to make a conclusion about a class; you could assign a class label with a vote of greater than 25%."
def print_output():
    output = my_method()
    text_area.insert(tk.END, output)



def open_file():
    file_path = filedialog.askopenfilename()
    if file_path.endswith('.xlsx'):
        df = pd.read_excel(file_path)
        text.delete('1.0', tk.END)
        text.insert(tk.END, df.to_string())
        

# Create a button to start the process
def start_process():
    status_label.config(text="Processing...")
    df = pd.read_excel("C://Users//tanta//OneDrive//Desktop//Final Project//Final_mapped.xlsx")
    for i in range(df.shape[0]):
        if df.match[i]==1:
            from notifypy import Notify
            notification = Notify()
            notification.title = "ALERT,ALERT,ALERT!!!!"
            notification.message = "Block IP ",df.SOURCE_IP[i]
            notification.audio = "C://Users//tanta//OneDrive//Desktop//Final Project//beep-05.wav"
            notification.send()
            time.sleep(8)
    status_label.config(text="Process complete")
    
    
    
def open_file_dialog():
    file_path = filedialog.askopenfilename(filetypes=[("Excel files", "*.xlsx")])
    if file_path:
        df = pd.read_excel(file_path)
        y=df['Class_Type']
        x=df.drop(['Class_Type'],axis=1)
        
       
        scalar=MinMaxScaler()
        new_x=scalar.fit_transform(x)
        new_x
        
       
        xtrain,xtest,ytrain,ytest=train_test_split(new_x,y,test_size=0.2,random_state=42)

        
        knn_model=KNeighborsClassifier(11,algorithm='auto')
        knn_model.fit(xtrain,ytrain)
        y_predict_knn=knn_model.predict(xtest)
        score = knn_model.score(x, y)
        label.config(text=f"Accuracy for the dataset is: {score*100}% ",font=("Times New Roman", 20))
        #confusion_matrix(ytest,y_predict_knn)
        
        
text_area = tk.Text(root,height=15,width=80)
text_area.pack()
    
#text_box = tk.Text(root, height=10, width=50)
#text_box.pack()

#textbox = tk.Entry(root)


button = tk.Button(root, text='INPUT FILE', command=open_file, height=3, width=20)
button.pack()

upload_button = tk.Button(root, text="TRAIN THE MODEL AND FIND ACCURACY", font=button_font, command=open_file_dialog ,height=3,width=35)
upload_button.pack(pady=10)


button = tk.Button(root, text="Description of the Model Used", command=print_output)
button.pack()
    
    
button = tk.Button(root, text='FIND ATTACK',font=button_font, command=start_process,height=3, width=30)
button.pack(pady=10)




#text = tk.Text(root,width=190)
#text.pack()

label = tk.Label(root, text="")
label.pack()

#button = tk.Button(root, text="Add Text", command=add_text)
#button.pack()

#text_area = tk.Text(root,font=("Times New Roman", 12) ,width=85, height=3)
#text_area.pack()

text = tk.Text(root,width=190)
text.pack(pady=10)



#scrollbar.config(command=text_box.yview)


root.tk_setPalette(background='black', foreground='white', activeBackground='pink', activeForeground='red')

root.mainloop()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(

# %%
import tkinter as tk
from tkinter import *
import pandas as pd
from tkinter import filedialog
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import time



# Create a GUI
root = tk.Tk()
root.title("INTRUSION DETECTION SYSTEM")
root.geometry("300x100")


# Create a label to display status
status_label = tk.Label(root, text="INTRUSION DETECTION SYSTEM",font=("Harrington", 20))
status_label.pack()


button_font = ('SimSun', 15)

def open_file():
    file_path = filedialog.askopenfilename()
    if file_path.endswith('.xlsx'):
        df = pd.read_excel(file_path)
        text.delete('1.0', tk.END)
        text.insert(tk.END, df.to_string())
        
        

    
def my_method():
    return "The k-nearest neighbors algorithm, also known as KNN or k-NN, is a non-parametric, supervised learning classifier, which uses proximity to make classifications or predictions about the grouping of an individual data point.For classification problems, a class label is assigned on the basis of a majority vote—i.e. the label that is most frequently represented around a given data point is used. While this is technically considered “plurality voting”, the term, “majority vote” is more commonly used in literature.The distinction between these terminologies is that “majority voting” technically requires a majority of greater than 50%, which primarily works when there are only two categories. When you have multiple classes—e.g. four categories, you don’t necessarily need 50% of the vote to make a conclusion about a class; you could assign a class label with a vote of greater than 25%."
def print_output():
    output = my_method()
    text_area.insert(tk.END, output)



def open_file():
    file_path = filedialog.askopenfilename()
    if file_path.endswith('.xlsx'):
        df = pd.read_excel(file_path)
        text.delete('1.0', tk.END)
        text.insert(tk.END, df.to_string())
        

# Create a button to start the process
def start_process():
    status_label.config(text="Processing...")
    df = pd.read_excel("C://Users//tanta//OneDrive//Desktop//Final Project//Final_mapped.xlsx")
    for i in range(df.shape[0]):
        if df.match[i]==1:
            from notifypy import Notify
            notification = Notify()
            notification.title = "ALERT,ALERT,ALERT!!!!"
            notification.message = "Block IP ",df.SOURCE_IP[i]
            notification.audio = "C://Users//tanta//OneDrive//Desktop//Final Project//beep-05.wav"
            notification.send()
            time.sleep(8)
    status_label.config(text="Process complete")
    
    
    
def open_file_dialog():
    file_path = filedialog.askopenfilename(filetypes=[("Excel files", "*.xlsx")])
    if file_path:
        df = pd.read_excel(file_path)
        y=df['Class_Type']
        x=df.drop(['Class_Type'],axis=1)
        
       
        scalar=MinMaxScaler()
        new_x=scalar.fit_transform(x)
        new_x
        
       
        xtrain,xtest,ytrain,ytest=train_test_split(new_x,y,test_size=0.2,random_state=42)

        
        knn_model=KNeighborsClassifier(11,algorithm='auto')
        knn_model.fit(xtrain,ytrain)
        y_pred =knn_model.predict(xtest)
        acc =knn_model.score(ytest,y_pred)
        label.config(text=f"Accuracy: {acc:.2f}")

    
    
text_area = tk.Text(root,height=15,width=80)
text_area.pack()
    
#text_box = tk.Text(root, height=10, width=50)
#text_box.pack()

#textbox = tk.Entry(root)


button = tk.Button(root, text='INPUT FILE', command=open_file, height=3, width=20)
button.pack()

upload_button = tk.Button(root, text="TRAIN THE MODEL AND FIND ACCURACY", font=button_font, command=open_file_dialog ,height=3,width=35)
upload_button.pack(pady=10)

lr_button = tk.Button(root, text="kneighbors", command=lambda: calculate_accuracy("K-Nearest Neighbors",knn_model))
lr_button.pack()

button = tk.Button(root, text="Description of the Model Used", command=print_output)
button.pack()
    
    
button = tk.Button(root, text='FIND ATTACK',font=button_font, command=start_process,height=3, width=30)
button.pack(pady=10)




#text = tk.Text(root,width=190)
#text.pack()

label = tk.Label(root, text="")
label.pack()

#button = tk.Button(root, text="Add Text", command=add_text)
#button.pack()

#text_area = tk.Text(root,font=("Times New Roman", 12) ,width=85, height=3)
#text_area.pack()

text = tk.Text(root,width=190)
text.pack(pady=10)



#scrollbar.config(command=text_box.yview)


root.tk_setPalette(background='black', foreground='white', activeBackground='pink', activeForeground='red')

root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\Users\tanta\AppData\Local\Temp\ipykernel_8772\1703418546.py", line 92, in open_file_dialog
#     acc = knn_model.score(ytest,y_pred)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py", line 651, in score
#     return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 214, in predict
#     neigh_dist, neigh_ind = self.kneighbors(X)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 717, in kneighbors
#     X = self._validate_data(X, accept_sparse="csr", reset=False)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py", line 566, in _validate_data
#     X = check_array(X, **check_params)
# ...
